# %%
df = pd.read_sql(
    """
    SELECT
      id,
      name
    FROM users
    WHERE
      active = 1
    """,
    conn,
)

# %%
cursor.execute(
    """
    SELECT
      COUNT(*)
    FROM orders
    WHERE
      status = 'completed'
    """
)
