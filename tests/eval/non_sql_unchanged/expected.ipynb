# %%
x = 42
y = x**2
print(f"Result: {y}")

# %%
import os

path = os.path.join("/tmp", "data.csv")

# %%
def fibonacci(n):
    a, b = 0, 1
    for _ in range(n):
        a, b = b, a + b
    return a
