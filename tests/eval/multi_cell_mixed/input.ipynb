# %% [markdown]
# # Data Analysis
# This notebook analyzes user data.

# %%
import pandas as pd
import numpy as np

# %%
query = "select id, name from users where active = 1"

# %%
df = pd.DataFrame({'a': [1, 2, 3]})

# %% [markdown]
# ## Results

# %%
result = "select count(*) as total from orders"
