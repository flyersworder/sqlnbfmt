# %% [markdown]
# # Data Analysis
# This notebook analyzes user data.

# %%
import pandas as pd
import numpy as np

# %%
query = """
SELECT
  id,
  name
FROM users
WHERE
  active = 1
"""

# %%
df = pd.DataFrame({'a': [1, 2, 3]})

# %% [markdown]
# ## Results

# %%
result = """
SELECT
  COUNT(*) AS total
FROM orders
"""
