# %%
# %sql SELECT * FROM users WHERE active = 1

# %%
# %%sql
# SELECT
#   id,
#   name,
#   email
# FROM users
# WHERE
#   active = 1
# ORDER BY
#   name

# %%
# Query with comment
# %%sql
SELECT
  COUNT(*)
FROM orders
